# %% [markdown]
# ![来来来](https://cdn.cubegoal.com/app_static/images/championship/upload/ddf819e8f3dd513fb5d837a7444d5e598cbfc88e.gif)

# %% [markdown]
# <img src='C:\\Users\\zr\\Desktop\\zhaopian\\手机照片\\IMG_20140203_202936.jpg',width=800>

# %% [markdown]
# <img src='file:///C:/Users/zr/wanmen/study_log/0114/IMG_20140203_202936.jpg' />

# %%
#  <img src='./IMG_20140203_202936.jpg' ,width=200 />

# %% [markdown]
# <img src='./IMG_20140203_202936.jpg',width=200 />

# %%
from IPython.display import Image

# %%
Image(filename='./IMG_20140203_202936.jpg' ,width=200)
